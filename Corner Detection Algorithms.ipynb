# %% [markdown]
# ###1.Implement the Harris corner detector to find and visualize corners in a grayscale image.

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
# %matplotlib inline
image = cv2.imread('/content/download (9).jpeg')
image_copy = np.copy(image)
image_copy = cv2.cvtColor(image_copy, cv2.COLOR_BGR2RGB)
plt.imshow(image_copy)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(224.5), np.float64(224.5), np.float64(-0.5))

# %%
gray = cv2.cvtColor(image_copy, cv2.COLOR_RGB2GRAY)
gray = np.float32(gray)
dst = cv2.cornerHarris(gray, 2, 3, 0.04)
dst = cv2.dilate(dst, None)

image_copy[dst > 0.01 * dst.max()] = [2,250,0]
plt.figure(figsize=(8, 6))
plt.imshow(image_copy)
plt.title('Harris Corners on Original Image')
plt.axis('off')
plt.show()

# %%
image = cv2.imread('/content/images (6).jpeg')
image_copy = np.copy(image)
image_copy = cv2.cvtColor(image_copy, cv2.COLOR_BGR2RGB)
plt.imshow(image_copy)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(224.5), np.float64(224.5), np.float64(-0.5))

# %%
gray = cv2.cvtColor(image_copy, cv2.COLOR_RGB2GRAY)
gray = np.float32(gray)
dst = cv2.cornerHarris(gray, 2, 3, 0.04)
dst = cv2.dilate(dst, None)

image_copy[dst > 0.01 * dst.max()] = [2,250,0]
plt.figure(figsize=(8, 6))
plt.imshow(image_copy)
plt.title('Harris Corners on Original Image')
plt.axis('off')
plt.show()

# %%
image = cv2.imread('/content/images (7).jpeg')
image_copy = np.copy(image)
image_copy = cv2.cvtColor(image_copy, cv2.COLOR_BGR2RGB)
plt.imshow(image_copy)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(167.5), np.float64(-0.5))

# %%
gray = cv2.cvtColor(image_copy, cv2.COLOR_RGB2GRAY)
gray = np.float32(gray)
dst = cv2.cornerHarris(gray, 2, 3, 0.04)
dst = cv2.dilate(dst, None)

image_copy[dst > 0.01 * dst.max()] = [2,250,0]
plt.figure(figsize=(8, 6))
plt.imshow(image_copy)
plt.title('Harris Corners on Original Image')
plt.axis('off')
plt.show()

# %% [markdown]
# ###2.Use the Shi-Tomasi corner detector to identify and mark corner points in an image.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('/content/download (9).jpeg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_copy = image.copy()

gray = cv2.cvtColor(image_copy, cv2.COLOR_RGB2GRAY)
gray = np.float32(gray)

corners = cv2.goodFeaturesToTrack(gray, 100, 0.01, 10)
corners = corners.astype(int)

for corner in corners:
    x, y = corner.ravel()
    cv2.circle(image_copy, (x, y), 4, (0, 255, 0), -1)

plt.figure(figsize=(8, 6))
plt.imshow(image_copy)
plt.title('Shi-Tomasi Corners')
plt.axis('off')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('/content/images (6).jpeg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_copy = image.copy()

gray = cv2.cvtColor(image_copy, cv2.COLOR_RGB2GRAY)
gray = np.float32(gray)

corners = cv2.goodFeaturesToTrack(gray, 100, 0.01, 10)
corners = corners.astype(int)

for corner in corners:
    x, y = corner.ravel()
    cv2.circle(image_copy, (x, y), 4, (0, 255, 0), -1)

plt.figure(figsize=(8, 6))
plt.imshow(image_copy)
plt.title('Shi-Tomasi Corners')
plt.axis('off')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('/content/images (7).jpeg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_copy = image.copy()

gray = cv2.cvtColor(image_copy, cv2.COLOR_RGB2GRAY)
gray = np.float32(gray)

corners = cv2.goodFeaturesToTrack(gray, 100, 0.01, 10)
corners = corners.astype(int)

for corner in corners:
    x, y = corner.ravel()
    cv2.circle(image_copy, (x, y), 4, (0, 255, 0), -1)

plt.figure(figsize=(8, 6))
plt.imshow(image_copy)
plt.title('Shi-Tomasi Corners')
plt.axis('off')
plt.show()

# %% [markdown]
# ###3.Moravec Corners Detection Algorithm

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('/content/download (9).jpeg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
gray = np.float32(gray)

window_size = 3
threshold = 50000
offsets = [(-1, 0), (1, 0), (0, -1), (0, 1)]
rows, cols = gray.shape
response = np.zeros_like(gray)

for y in range(window_size, rows - window_size):
    for x in range(window_size, cols - window_size):
        min_ssd = float('inf')
        for dx, dy in offsets:
            ssd = 0
            for i in range(-window_size, window_size + 1):
                for j in range(-window_size, window_size + 1):
                    try:
                        diff = gray[y + i, x + j] - gray[y + i + dy, x + j + dx]
                        ssd += diff ** 2
                    except:
                        continue
            min_ssd = min(min_ssd, ssd)
        response[y, x] = min_ssd

image_copy = image.copy()
for y in range(rows):
    for x in range(cols):
        if response[y, x] > threshold:
            cv2.circle(image_copy, (x, y), 1, (255, 0, 0), -1)  # Blue dots

plt.figure(figsize=(8, 6))
plt.imshow(image_copy)
plt.title('Moravec Corners')
plt.axis('off')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('/content/images (6).jpeg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
gray = np.float32(gray)

window_size = 3
threshold = 50000
offsets = [(-1, 0), (1, 0), (0, -1), (0, 1)]

rows, cols = gray.shape
response = np.zeros_like(gray)

for y in range(window_size, rows - window_size):
    for x in range(window_size, cols - window_size):
        min_ssd = float('inf')
        for dx, dy in offsets:
            ssd = 0
            for i in range(-window_size, window_size + 1):
                for j in range(-window_size, window_size + 1):
                    try:
                        diff = gray[y + i, x + j] - gray[y + i + dy, x + j + dx]
                        ssd += diff ** 2
                    except:
                        continue
            min_ssd = min(min_ssd, ssd)
        response[y, x] = min_ssd

image_copy = image.copy()
for y in range(rows):
    for x in range(cols):
        if response[y, x] > threshold:
            cv2.circle(image_copy, (x, y), 1, (255, 0, 0), -1)

plt.figure(figsize=(8, 6))
plt.imshow(image_copy)
plt.title('Moravec Corners')
plt.axis('off')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('/content/images (7).jpeg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
gray = np.float32(gray)

window_size = 3
threshold = 50000
offsets = [(-1, 0), (1, 0), (0, -1), (0, 1)]

rows, cols = gray.shape
response = np.zeros_like(gray)

for y in range(window_size, rows - window_size):
    for x in range(window_size, cols - window_size):
        min_ssd = float('inf')
        for dx, dy in offsets:
            ssd = 0
            for i in range(-window_size, window_size + 1):
                for j in range(-window_size, window_size + 1):
                    try:
                        diff = gray[y + i, x + j] - gray[y + i + dy, x + j + dx]
                        ssd += diff ** 2
                    except:
                        continue
            min_ssd = min(min_ssd, ssd)
        response[y, x] = min_ssd

image_copy = image.copy()
for y in range(rows):
    for x in range(cols):
        if response[y, x] > threshold:
            cv2.circle(image_copy, (x, y), 1, (255, 0, 0), -1)

plt.figure(figsize=(8, 6))
plt.imshow(image_copy)
plt.title('Moravec Corners')
plt.axis('off')
plt.show()
